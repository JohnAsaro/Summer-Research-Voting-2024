# %% [markdown]
# Plotting voting results for different voting rules, comparing the results based on average theta coefficent
#
# (normal distrubution)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np


#mpl.rcParams.update(mpl.rcParamsDefault) #to reset style
style.use('ggplot')
style.use('tableau-colorblind10')
style.use('seaborn-v0_8-paper')

# %%
df = pd.read_csv('voting_results_k_1_normal.csv')

print(df.columns)

average_theta_values = {
    'Plurality': df['Plurality θ'].mean(),
    'Borda': df['Borda θ'].mean(),
    'Copeland': df['Copeland θ'].mean(),
    'STV': df['STV θ'].mean(),
    'Greatest θ-Winning Set': df['Greatest θ Coefficient'].mean()
}
# Out:
# Index(['index', 'n', 'm', 'Plurality', 'Plurality θ', 'Borda', 'Borda θ',
#        'Copeland', 'Copeland θ', 'STV', 'STV θ', 'Greatest θ-winning Set',
#        'Greatest θ Coefficient'],
#       dtype='object')

# %% [markdown]
# Plot average theta vaule for each voting rule on bar graph

# %%
#Plotting
colors = ['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen']
plt.figure(figsize=(10, 6))
bars = plt.bar(average_theta_values.keys(), average_theta_values.values(), color=colors)

#Adding a legend
#plt.legend(bars, average_theta_values.keys(), loc="center left", bbox_to_anchor=(1, 0.5))


#Adding titles and labels
plt.xlabel('Voting Rule', labelpad=15)  
plt.title('Average θ for Each Voting Rule across all different m values (k = 1/normal distrubution)', pad=20)
plt.ylabel('Average θ', labelpad=15)

for bar in bars: #Add the actual values on top of the bars
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 4), ha='center', va='bottom')


#Adjust the plot to fit the legend
plt.tight_layout()

#Show the plot
plt.show()

# %% [markdown]
# Generate legend

# %%
#Define the voting rules and corresponding colors
voting_rules = ['Plurality θ', 'Borda θ', 'Copeland θ', 'STV θ', 'Greatest θ Coefficient']
colors = ['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen']

#Create a figure for the legend
plt.figure(figsize=(2, 2))

#Plot dummy bars just to generate the legend
bars = [plt.bar(0, 0, color=color) for color in colors]  # Dummy bars

#Create the legend
plt.legend(bars, voting_rules, loc="center", ncol=1, frameon=False)

#Turn off axis since we're only interested in the legend
plt.axis('off')

#Save the legend to a file
#plt.savefig('voting_rules_legend.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Grouping by number of candidates (averages)

# %%
group_m3_avg  = df.loc[df['m'] == 3].groupby("m").agg(Plurality_Theta_avg = ("Plurality θ", "mean"),
                                                                                  Borda_Theta_avg = ("Borda θ", "mean"), 
                                                                                Copeland_Theta_avg = ("Copeland θ", "mean"),
                                                                                  STV_Theta_avg = ("STV θ", "mean"), 
                                                                                  Greatest_Theta_Winning_Set_avg = ("Greatest θ Coefficient", "mean"))

group_m5_avg  = df.loc[df['m'] == 5].groupby("m").agg(Plurality_Theta_avg = ("Plurality θ", "mean"),
                                                                                  Borda_Theta_avg = ("Borda θ", "mean"), 
                                                                                Copeland_Theta_avg = ("Copeland θ", "mean"),
                                                                                  STV_Theta_avg = ("STV θ", "mean"), 
                                                                                  Greatest_Theta_Winning_Set_avg = ("Greatest θ Coefficient", "mean"))

group_m10_avg  = df.loc[df['m'] == 10].groupby("m").agg(Plurality_Theta_avg = ("Plurality θ", "mean"),
                                                                                  Borda_Theta_avg = ("Borda θ", "mean"), 
                                                                                Copeland_Theta_avg = ("Copeland θ", "mean"),
                                                                                  STV_Theta_avg = ("STV θ", "mean"), 
                                                                                  Greatest_Theta_Winning_Set_avg = ("Greatest θ Coefficient", "mean"))

group_m30_avg  = df.loc[df['m'] == 30].groupby("m").agg(Plurality_Theta_avg = ("Plurality θ", "mean"),
                                                                                  Borda_Theta_avg = ("Borda θ", "mean"), 
                                                                                Copeland_Theta_avg = ("Copeland θ", "mean"),
                                                                                  STV_Theta_avg = ("STV θ", "mean"), 
                                                                                  Greatest_Theta_Winning_Set_avg = ("Greatest θ Coefficient", "mean"))

group_m50_avg  = df.loc[df['m'] == 50].groupby("m").agg(Plurality_Theta_avg = ("Plurality θ", "mean"),
                                                                                  Borda_Theta_avg = ("Borda θ", "mean"), 
                                                                                Copeland_Theta_avg = ("Copeland θ", "mean"),
                                                                                  STV_Theta_avg = ("STV θ", "mean"), 
                                                                                  Greatest_Theta_Winning_Set_avg = ("Greatest θ Coefficient", "mean"))

group_m100_avg  = df.loc[df['m'] == 100].groupby("m").agg(Plurality_Theta_avg = ("Plurality θ", "mean"),
                                                                                  Borda_Theta_avg = ("Borda θ", "mean"), 
                                                                                Copeland_Theta_avg = ("Copeland θ", "mean"),
                                                                                  STV_Theta_avg = ("STV θ", "mean"), 
                                                                                  Greatest_Theta_Winning_Set_avg = ("Greatest θ Coefficient", "mean"))

plurality_avg_all_m = [group_m3_avg['Plurality_Theta_avg'].values[0], group_m5_avg['Plurality_Theta_avg'].values[0], group_m10_avg['Plurality_Theta_avg'].values[0], group_m30_avg['Plurality_Theta_avg'].values[0], group_m50_avg['Plurality_Theta_avg'].values[0], group_m100_avg['Plurality_Theta_avg'].values[0]]
borda_avg_all_m = [group_m3_avg['Borda_Theta_avg'].values[0], group_m5_avg['Borda_Theta_avg'].values[0], group_m10_avg['Borda_Theta_avg'].values[0], group_m30_avg['Borda_Theta_avg'].values[0], group_m50_avg['Borda_Theta_avg'].values[0], group_m100_avg['Borda_Theta_avg'].values[0]]
copeland_avg_all_m = [group_m3_avg['Copeland_Theta_avg'].values[0], group_m5_avg['Copeland_Theta_avg'].values[0], group_m10_avg['Copeland_Theta_avg'].values[0], group_m30_avg['Copeland_Theta_avg'].values[0], group_m50_avg['Copeland_Theta_avg'].values[0], group_m100_avg['Copeland_Theta_avg'].values[0]]
stv_avg_all_m = [group_m3_avg['STV_Theta_avg'].values[0], group_m5_avg['STV_Theta_avg'].values[0], group_m10_avg['STV_Theta_avg'].values[0], group_m30_avg['STV_Theta_avg'].values[0], group_m50_avg['STV_Theta_avg'].values[0], group_m100_avg['STV_Theta_avg'].values[0]]
greatest_theta_winning_set_avg_all_m = [group_m3_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m5_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m10_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m30_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m50_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m100_avg['Greatest_Theta_Winning_Set_avg'].values[0]]

# %% [markdown]
# Group by number of candidates (max)

# %%
group_m3_max  = df.loc[df['m'] == 3].groupby("m").agg(Plurality_Theta_max = ("Plurality θ", "max"),
                                                                                  Borda_Theta_max = ("Borda θ", "max"), 
                                                                                  Copeland_Theta_max = ("Copeland θ", "max"), 
                                                                                  STV_Theta_max = ("STV θ", "max"), 
                                                                                  Greatest_Theta_Winning_Set_max = ("Greatest θ Coefficient", "max"))

group_m5_max  = df.loc[df['m'] == 5].groupby("m").agg(Plurality_Theta_max = ("Plurality θ", "max"),
                                                                                  Borda_Theta_max = ("Borda θ", "max"), 
                                                                                  Copeland_Theta_max = ("Copeland θ", "max"), 
                                                                                  STV_Theta_max = ("STV θ", "max"), 
                                                                                  Greatest_Theta_Winning_Set_max = ("Greatest θ Coefficient", "max"))

group_m10_max  = df.loc[df['m'] == 10].groupby("m").agg(Plurality_Theta_max = ("Plurality θ", "max"),
                                                                                  Borda_Theta_max = ("Borda θ", "max"), 
                                                                                  Copeland_Theta_max = ("Copeland θ", "max"), 
                                                                                  STV_Theta_max = ("STV θ", "max"), 
                                                                                  Greatest_Theta_Winning_Set_max = ("Greatest θ Coefficient", "max"))

group_m30_max  = df.loc[df['m'] == 30].groupby("m").agg(Plurality_Theta_max = ("Plurality θ", "max"),
                                                                                  Borda_Theta_max = ("Borda θ", "max"), 
                                                                                  Copeland_Theta_max = ("Copeland θ", "max"), 
                                                                                  STV_Theta_max = ("STV θ", "max"), 
                                                                                  Greatest_Theta_Winning_Set_max = ("Greatest θ Coefficient", "max"))


group_m50_max  = df.loc[df['m'] == 50].groupby("m").agg(Plurality_Theta_max = ("Plurality θ", "max"),
                                                                                  Borda_Theta_max = ("Borda θ", "max"), 
                                                                                  Copeland_Theta_max = ("Copeland θ", "max"), 
                                                                                  STV_Theta_max = ("STV θ", "max"), 
                                                                                  Greatest_Theta_Winning_Set_max = ("Greatest θ Coefficient", "max"))

group_m100_max  = df.loc[df['m'] == 100].groupby("m").agg(Plurality_Theta_max = ("Plurality θ", "max"),
                                                                                  Borda_Theta_max = ("Borda θ", "max"), 
                                                                                  Copeland_Theta_max = ("Copeland θ", "max"), 
                                                                                  STV_Theta_max = ("STV θ", "max"), 
                                                                                  Greatest_Theta_Winning_Set_max = ("Greatest θ Coefficient", "max"))

plurality_max_all_m = [group_m3_max['Plurality_Theta_max'].values[0], group_m5_max['Plurality_Theta_max'].values[0], group_m10_max['Plurality_Theta_max'].values[0], group_m30_max['Plurality_Theta_max'].values[0], group_m50_max['Plurality_Theta_max'].values[0], group_m100_max['Plurality_Theta_max'].values[0]]
borda_max_all_m = [group_m3_max['Borda_Theta_max'].values[0], group_m5_max['Borda_Theta_max'].values[0], group_m10_max['Borda_Theta_max'].values[0], group_m30_max['Borda_Theta_max'].values[0], group_m50_max['Borda_Theta_max'].values[0], group_m100_max['Borda_Theta_max'].values[0]]
copeland_max_all_m = [group_m3_max['Copeland_Theta_max'].values[0], group_m5_max['Copeland_Theta_max'].values[0], group_m10_max['Copeland_Theta_max'].values[0], group_m30_max['Copeland_Theta_max'].values[0], group_m50_max['Copeland_Theta_max'].values[0], group_m100_max['Copeland_Theta_max'].values[0]]
stv_max_all_m = [group_m3_max['STV_Theta_max'].values[0], group_m5_max['STV_Theta_max'].values[0], group_m10_max['STV_Theta_max'].values[0], group_m30_max['STV_Theta_max'].values[0], group_m50_max['STV_Theta_max'].values[0], group_m100_max['STV_Theta_max'].values[0]]
greatest_theta_winning_set_max_all_m = [group_m3_max['Greatest_Theta_Winning_Set_max'].values[0], group_m5_max['Greatest_Theta_Winning_Set_max'].values[0], group_m10_max['Greatest_Theta_Winning_Set_max'].values[0], group_m30_max['Greatest_Theta_Winning_Set_max'].values[0], group_m50_max['Greatest_Theta_Winning_Set_max'].values[0], group_m100_max['Greatest_Theta_Winning_Set_max'].values[0]]

# %% [markdown]
# Plot different m values

# %%
#Extract data

distribution = group_m3_avg.index
labels = average_theta_values.keys()
values = group_m3_avg.iloc[0].values

#Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen'])
bars = plt.bar(average_theta_values.keys(), values, color=colors)

#Define x-axis positions for the bars
#x = np.arange(len(distribution))

#Add labels and title
plt.xlabel('Voting Rule', labelpad=15)
plt.ylabel('Average θ', labelpad=15)
plt.title('Average θ for m = 3 (k = 1/normal distrubution)', pad=20)
#plt.xticks(x, distribution)
#plt.ylim(0,1)
for bar in bars: #Add the actual values on top of the bars
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 4), ha='center', va='bottom')

#Show the plot
plt.tight_layout()
plt.show()
group_m3_avg.head()
# Out:
#    Plurality_Theta_avg  Borda_Theta_avg  Copeland_Theta_avg  STV_Theta_avg  \
# m
# 3             0.506072         0.509028            0.509356       0.508772
#
#    Greatest_Theta_Winning_Set_avg
# m
# 3                        0.509844

# %%
#Extract data

distribution = group_m5_avg.index
labels = average_theta_values.keys()
values = group_m5_avg.iloc[0].values

#Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen'])
bars = plt.bar(average_theta_values.keys(), values, color=colors)

#Define x-axis positions for the bars
#x = np.arange(len(distribution))

#Add labels and title
plt.xlabel('Voting Rule', labelpad=15)
plt.ylabel('Average θ', labelpad=15)
plt.title('Average θ for m = 5 (k = 1/normal distrubution)', pad=20)
#plt.xticks(x, distribution)
#plt.ylim(0,1)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 4), ha='center', va='bottom')
    
#Show the plot
plt.tight_layout()
group_m5_avg.head()
# Out:
#    Plurality_Theta_avg  Borda_Theta_avg  Copeland_Theta_avg  STV_Theta_avg  \
# m
# 5             0.498096          0.50406            0.504368       0.503416
#
#    Greatest_Theta_Winning_Set_avg
# m
# 5                        0.505592

# %%
#Extract data

distribution = group_m10_avg.index
labels = average_theta_values.keys()
values = group_m10_avg.iloc[0].values

#Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen'])
bars = plt.bar(average_theta_values.keys(), values, color=colors)

#Define x-axis positions for the bars
#x = np.arange(len(distribution))

#Add labels and title
plt.xlabel('Voting Rule', labelpad=15)
plt.ylabel('Average θ', labelpad=15)
plt.title('Average θ for m = 10 (k = 1/normal distrubution)', pad=20)
#plt.xticks(x, distribution)
#plt.ylim(0,1)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 4), ha='center', va='bottom')
    
#Show the plot
plt.tight_layout()
group_m10_avg.head()
# Out:
#     Plurality_Theta_avg  Borda_Theta_avg  Copeland_Theta_avg  STV_Theta_avg  \
# m
# 10             0.486608         0.498564            0.498764       0.495996
#
#     Greatest_Theta_Winning_Set_avg
# m
# 10                        0.500892

# %%
#Extract data

distribution = group_m30_avg.index
labels = average_theta_values.keys()
values = group_m30_avg.iloc[0].values

#Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen'])
bars = plt.bar(average_theta_values.keys(), values, color=colors)

#Define x-axis positions for the bars
#x = np.arange(len(distribution))

#Add labels and title
plt.xlabel('Voting Rule', labelpad=15)
plt.ylabel('Average θ', labelpad=15)
plt.title('Average θ for m = 30 (k = 1/normal distrubution)', pad=20)
#plt.xticks(x, distribution)
#plt.ylim(0,1)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 4), ha='center', va='bottom')
    
#Show the plot
plt.tight_layout()
group_m30_avg.head()
# Out:
#     Plurality_Theta_avg  Borda_Theta_avg  Copeland_Theta_avg  STV_Theta_avg  \
# m
# 30             0.472908         0.493336            0.493828       0.487092
#
#     Greatest_Theta_Winning_Set_avg
# m
# 30                        0.496224

# %%
#Extract data

distribution = group_m50_avg.index
labels = average_theta_values.keys()
values = group_m50_avg.iloc[0].values

#Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen'])
bars = plt.bar(average_theta_values.keys(), values, color=colors)

#Define x-axis positions for the bars
#x = np.arange(len(distribution))

#Add labels and title
plt.xlabel('Voting Rule', labelpad=15)
plt.ylabel('Average θ', labelpad=15)
plt.title('Average θ for m = 50 (k = 1/normal distrubution)', pad=20)
#plt.xticks(x, distribution)
#plt.ylim(0,1)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 4), ha='center', va='bottom')
    
#Show the plot
plt.tight_layout()
group_m50_avg.head()
# Out:
#     Plurality_Theta_avg  Borda_Theta_avg  Copeland_Theta_avg  STV_Theta_avg  \
# m
# 50             0.468592         0.491548            0.492048        0.48296
#
#     Greatest_Theta_Winning_Set_avg
# m
# 50                        0.494492

# %%
#Extract data

distribution = group_m100_avg.index
labels = average_theta_values.keys()
values = group_m100_avg.iloc[0].values

#Create the bar graph
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen'])
bars = plt.bar(average_theta_values.keys(), values, color=colors)

#Define x-axis positions for the bars
#x = np.arange(len(distribution))

#Add labels and title
plt.xlabel('Voting Rule', labelpad=15)
plt.ylabel('Average θ', labelpad=15)
plt.title('Average θ for m = 100 (k = 1/normal distrubution)', pad=20)
#plt.xticks(x, distribution)
#plt.ylim(0,1)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 4), ha='center', va='bottom')
    
#Show the plot
plt.tight_layout()
group_m100_avg.head()
# Out:
#      Plurality_Theta_avg  Borda_Theta_avg  Copeland_Theta_avg  STV_Theta_avg  \
# m
# 100             0.461484         0.488356            0.488948         0.4786
#
#      Greatest_Theta_Winning_Set_avg
# m
# 100                        0.491768

# %% [markdown]
# As m rises change in average theta

# %%
CB_color_cycle = ['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen']

#Create results dictionary
results = {
    "m": [3, 5, 10, 30, 50, 100],
    "Plurality θ": plurality_avg_all_m,
    "Borda θ": borda_avg_all_m,
    "Copeland θ": copeland_avg_all_m,
    "STV θ": stv_avg_all_m,
    "Greatest θ Coefficient": greatest_theta_winning_set_avg_all_m
}

#Extract data from results dictionary
m_values = results["m"]
plurality_theta = results["Plurality θ"]
borda_theta = results["Borda θ"]
copeland_theta = results["Copeland θ"]
stv_theta = results["STV θ"]
greatest_theta = results["Greatest θ Coefficient"]

#Plot the data
#plt.figure(figsize=(10, 6))

plt.plot(m_values, plurality_theta, label='Plurality θ', marker='s', color=CB_color_cycle[0])
plt.plot(m_values, borda_theta, label='Borda θ', marker='o', color=CB_color_cycle[1])
plt.plot(m_values, copeland_theta, label='Copeland θ', marker='^', color=CB_color_cycle[2])
plt.plot(m_values, stv_theta, label='STV θ', marker='v', color=CB_color_cycle[3])
plt.plot(m_values, greatest_theta, label='Greatest θ-Winning Set', marker = 'D', color=CB_color_cycle[4])

#Add labels and title
plt.xlabel('Number of Candidates (m)')
plt.ylabel('Theta (θ)')
plt.title("Change in Average θ as 'm' Grows (k = 1, Normal Distrubution)")

#Set limits
plt.ylim(0.4305, 0.710)

#Set x-axis ticks
plt.xticks(m_values)

#Add legend
plt.legend()

#Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# Same thing but cap m at 50

# %%
plurality_avg_all_m_capped = [group_m3_avg['Plurality_Theta_avg'].values[0], group_m5_avg['Plurality_Theta_avg'].values[0], group_m10_avg['Plurality_Theta_avg'].values[0], group_m30_avg['Plurality_Theta_avg'].values[0], group_m50_avg['Plurality_Theta_avg'].values[0]]
borda_avg_all_m_capped = [group_m3_avg['Borda_Theta_avg'].values[0], group_m5_avg['Borda_Theta_avg'].values[0], group_m10_avg['Borda_Theta_avg'].values[0], group_m30_avg['Borda_Theta_avg'].values[0], group_m50_avg['Borda_Theta_avg'].values[0]]
copeland_avg_all_m_capped = [group_m3_avg['Copeland_Theta_avg'].values[0], group_m5_avg['Copeland_Theta_avg'].values[0], group_m10_avg['Copeland_Theta_avg'].values[0], group_m30_avg['Copeland_Theta_avg'].values[0], group_m50_avg['Copeland_Theta_avg'].values[0]]
stv_avg_all_m_capped = [group_m3_avg['STV_Theta_avg'].values[0], group_m5_avg['STV_Theta_avg'].values[0], group_m10_avg['STV_Theta_avg'].values[0], group_m30_avg['STV_Theta_avg'].values[0], group_m50_avg['STV_Theta_avg'].values[0]]
greatest_theta_winning_set_avg_all_m_capped = [group_m3_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m5_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m10_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m30_avg['Greatest_Theta_Winning_Set_avg'].values[0], group_m50_avg['Greatest_Theta_Winning_Set_avg'].values[0]]

# %%
CB_color_cycle = ['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen']

#Create results dictionary
results = {
    "m": [3, 5, 10, 30, 50],
    "Plurality θ": plurality_avg_all_m_capped,
    "Borda θ": borda_avg_all_m_capped,
    "Copeland θ": copeland_avg_all_m_capped,
    "STV θ": stv_avg_all_m_capped,
    "Greatest θ Coefficient": greatest_theta_winning_set_avg_all_m_capped
}

#Extract data from results dictionary
m_values = results["m"]
plurality_theta = results["Plurality θ"]
borda_theta = results["Borda θ"]
copeland_theta = results["Copeland θ"]
stv_theta = results["STV θ"]
greatest_theta = results["Greatest θ Coefficient"]

#Plot the data
#plt.figure(figsize=(10, 6))

plt.plot(m_values, plurality_theta, label='Plurality θ', marker='s', color=CB_color_cycle[0])
plt.plot(m_values, borda_theta, label='Borda θ', marker='o', color=CB_color_cycle[1])
plt.plot(m_values, copeland_theta, label='Copeland θ', marker='^', color=CB_color_cycle[2])
plt.plot(m_values, stv_theta, label='STV θ', marker='v', color=CB_color_cycle[3])
plt.plot(m_values, greatest_theta, label='Greatest θ-Winning Set', marker = 'D', color=CB_color_cycle[4])

#Add labels and title
plt.xlabel('Number of Candidates (m)')
plt.ylabel('Theta (θ)')
plt.title("Change in Average θ as 'm' Grows (k = 1, Normal Distrubution)")

#Set limits
plt.ylim(0.4305, 0.710)

#Set x-axis ticks
plt.xticks(m_values)

#Add legend
plt.legend()

#Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# As m rises change in max theta

# %%
CB_color_cycle = ['skyblue', 'lightgreen', 'salmon', 'orange', 'lightseagreen']

#Create results dictionary
results = {
    "m": [3, 5, 10, 30, 50, 100],
    "Plurality θ": plurality_avg_all_m,
    "Borda θ": borda_avg_all_m,
    "Copeland θ": copeland_avg_all_m,
    "STV θ": stv_avg_all_m,
    "Greatest θ Coefficient": greatest_theta_winning_set_avg_all_m
}

#Extract data from results dictionary
m_values = results["m"]
plurality_theta = results["Plurality θ"]
borda_theta = results["Borda θ"]
copeland_theta = results["Copeland θ"]
stv_theta = results["STV θ"]
greatest_theta = results["Greatest θ Coefficient"]

#Plot the data
#plt.figure(figsize=(10, 6))

plt.plot(m_values, plurality_theta, label='Plurality θ', marker='s', color=CB_color_cycle[0])
plt.plot(m_values, borda_theta, label='Borda θ', marker='o', color=CB_color_cycle[1])
plt.plot(m_values, copeland_theta, label='Copeland θ', marker='^', color=CB_color_cycle[2])
plt.plot(m_values, stv_theta, label='STV θ', marker='v', color=CB_color_cycle[3])
plt.plot(m_values, greatest_theta, label='Greatest θ-Winning Set', marker = 'D', color=CB_color_cycle[4])

#Add labels and title
plt.xlabel('Number of Candidates (m)')
plt.ylabel('Theta (θ)')
plt.title("Change in Average θ as 'm' Grows (k = 1, Normal Distrubution)")

#Set limits
plt.ylim(0.4305, 0.710)

#Set x-axis ticks
plt.xticks(m_values)

#Add legend
plt.legend()

#Display the plot
plt.grid(True)
plt.show()
